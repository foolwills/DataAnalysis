# %% [markdown]
# # 时间序列分析学习

# %% [markdown]
# ## 第 1 周：Python 数据分析必备库（必学） 0316
# ### 目标：
# 能读数据、处理数据、画简单图
# ### 学习内容：
# NumPy 数组操作（重点）
# Pandas 基础：Series/DataFrame、读取 csv/excel
# 简单数据清洗：缺失值、重复值
# ### 实战任务：
# 加载一份气温 / 股票 / 销量公开数据
# 筛选、切片、统计均值 / 最值
# ### 本周产出：
# 能独立处理表格数据<br>
# [查看目标文档](./section_01.ipynb)

# %% [markdown]
# # 一级标题（最大）
# ## 二级标题
# ### 三级标题
# #### 四级标题

# %% [markdown]
# **加粗**
# *斜体*

# %% [markdown]
# # A/B 测试报告：推送文案优化
#
# ## 一、测试背景
# 优化会员激活率
#
# ## 二、测试方案
# - A组：利益点文案
# - B组：紧迫感文案
#
# ## 三、结果数据
# | 分组 | 打开率 | 激活率 |
# |-----|--------|--------|
# | A组 | 18.2%  | 9.5%   |
# | B组 | 12.1%  | 5.3%   |
#
# ## 四、结论
# **A组效果显著更优，建议全量上线。**
